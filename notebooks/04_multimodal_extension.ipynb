# %% [markdown]
# # 04 — Multimodal Extension
# Scaffold for adding image/PDF understanding to local RAG workflows.

# %%
from pathlib import Path
pdfs = list(Path('../sample_data').rglob('*.pdf'))
images = list(Path('../sample_data').rglob('*.png')) + list(Path('../sample_data').rglob('*.jpg'))
print('PDFs:', len(pdfs), 'Images:', len(images))

# %% [markdown]
# Next step: connect a local vision-language model and push extracted text/captions into the same vector index.
