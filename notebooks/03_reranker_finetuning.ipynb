# %% [markdown]
# # 03 — Reranker Fine-Tuning Starter
# Template workflow for lightweight reranker tuning with local data.

# %%
import pandas as pd
pairs = pd.DataFrame([
    {'query':'AI governance', 'positive':'Preserve source lineage and citations', 'negative':'Unrelated sports content'},
    {'query':'Enterprise workflow automation', 'positive':'Automate repeatable data tasks with traceability', 'negative':'Cooking recipe notes'}
])
pairs

# %% [markdown]
# Use this dataset with your preferred reranker trainer (e.g., sentence-transformers or QLoRA adapters).
